# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("airfoil_self_noise.dat", sep="\t", header=None)

# %%
df.columns = [
    "Frequency",
    "Angle_of_attack",
    "Chord_length",
    "Free_stream_velocity",
    "Suction_thickness",
    "Sound_pressure_level"
]

df.head()
# Out:
#    Frequency  Angle_of_attack  Chord_length  Free_stream_velocity  \
# 0        800              0.0        0.3048                  71.3
# 1       1000              0.0        0.3048                  71.3
# 2       1250              0.0        0.3048                  71.3
# 3       1600              0.0        0.3048                  71.3
# 4       2000              0.0        0.3048                  71.3
#
#    Suction_thickness  Sound_pressure_level
# 0           0.002663               126.201
# 1           0.002663               125.201
# 2           0.002663               125.951
# 3           0.002663               127.591
# 4           0.002663               127.461

# %%
mean_values = df.mean()
print("Mean:\n", mean_values)
# Out:
# Mean:
#  Frequency               2886.380572
# Angle_of_attack            6.782302
# Chord_length               0.136548
# Free_stream_velocity      50.860745
# Suction_thickness          0.011140
# Sound_pressure_level     124.835943
# dtype: float64

# %%
variance_values = df.var()
std_values = df.std()

print("\nVariance:\n", variance_values)
print("\nStandard Deviation:\n", std_values)
# Out:
# Variance:
#  Frequency               9.938717e+06
# Angle_of_attack         3.502424e+01
# Chord_length            8.749868e-03
# Free_stream_velocity    2.425116e+02
# Suction_thickness       1.729287e-04
# Sound_pressure_level    4.759146e+01
# dtype: float64
#
# Standard Deviation:
#  Frequency               3152.573137
# Angle_of_attack            5.918128
# Chord_length               0.093541
# Free_stream_velocity      15.572784
# Suction_thickness          0.013150
# Sound_pressure_level       6.898657
# dtype: float64

# %%
median_values = df.median()
print("\nMedian:\n", median_values)
# Out:
# Median:
#  Frequency               1600.000000
# Angle_of_attack            5.400000
# Chord_length               0.101600
# Free_stream_velocity      39.600000
# Suction_thickness          0.004957
# Sound_pressure_level     125.721000
# dtype: float64

# %%
kurtosis_values = df.kurt()
print("\nKurtosis:\n", kurtosis_values)

# %%
skewness_values = df.skew()
print("\nSkewness:\n", skewness_values)

# %%
range_values = df.max() - df.min()
print("\nRange:\n", range_values)
# Out:
# Range:
#  Frequency               19800.000000
# Angle_of_attack            22.200000
# Chord_length                0.279400
# Free_stream_velocity       39.600000
# Suction_thickness           0.058011
# Sound_pressure_level       37.607000
# dtype: float64

# %%
stats = pd.DataFrame({
    "Mean": df.mean(),
    "Variance": df.var(),
    "Standard Deviation": df.std(),
    "Median": df.median(),
    "Kurtosis": df.kurt(),
    "Skewness": df.skew(),
    "Range": df.max() - df.min()
})

stats
# Out:
#                              Mean      Variance  Standard Deviation  \
# Frequency             2886.380572  9.938717e+06         3152.573137
# Angle_of_attack          6.782302  3.502424e+01            5.918128
# Chord_length             0.136548  8.749868e-03            0.093541
# Free_stream_velocity    50.860745  2.425116e+02           15.572784
# Suction_thickness        0.011140  1.729287e-04            0.013150
# Sound_pressure_level   124.835943  4.759146e+01            6.898657
#
#                            Median  Kurtosis  Skewness         Range
# Frequency             1600.000000  5.708685  2.137084  19800.000000
# Angle_of_attack          5.400000 -0.412951  0.689164     22.200000
# Chord_length             0.101600 -1.037964  0.457457      0.279400
# Free_stream_velocity    39.600000 -1.563951  0.235852     39.600000
# Suction_thickness        0.004957  2.218903  1.702165      0.058011
# Sound_pressure_level   125.721000 -0.314187 -0.418952     37.607000
